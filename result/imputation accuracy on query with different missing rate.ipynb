# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
# data = pd.read_csv("figure4.csv")
data = pd.read_csv("figure8_2.csv")

# %%
data
# Out:
#    Subset Ratio  fmask  pearson_rna  pearson_adt  rmsle_rna  rmsle_adt
# 0    Subset 10%    0.1        0.966        0.932      0.301      0.468
# 1    Subset 10%    0.3        0.941        0.865      0.291      0.494
# 2    Subset 10%    0.5        0.664        0.761      0.286      0.563
# 3    Subset 10%    0.7        0.624        0.483      0.288      0.674
# 4    Subset 10%    0.9        0.230        0.176      0.301      0.871
# 5    Subset 20%    0.1        0.928        0.928      0.290      0.470
# 6    Subset 20%    0.3        0.635        0.667      0.293      0.507
# 7    Subset 20%    0.5        0.803        0.700      0.277      0.557
# 8    Subset 20%    0.7        0.568        0.448      0.279      0.703
# 9    Subset 20%    0.9        0.231        0.208      0.291      0.863
# 10   Subset 50%    0.1        0.891        0.918      0.291      0.452
# 11   Subset 50%    0.3        0.793        0.782      0.285      0.489
# 12   Subset 50%    0.5        0.701        0.603      0.282      0.576
# 13   Subset 50%    0.7        0.460        0.456      0.283      0.707
# 14   Subset 50%    0.9        0.261        0.238      0.295      0.853
# 15  Subset 100%    0.1        0.909        0.884      0.288      0.446
# 16  Subset 100%    0.3        0.870        0.799      0.281      0.493
# 17  Subset 100%    0.5        0.672        0.653      0.277      0.589
# 18  Subset 100%    0.7        0.525        0.421      0.279      0.710
# 19  Subset 100%    0.9        0.242        0.126      0.289      0.857

# %%
labels = ['Subset 10%', 'Subset 20%', 'Subset 50%', 'Subset 100%']

# x = np.arange(len(labels))  # the label locations
x = np.array([0, 0.6, 1.2, 1.8])
width = 0.07  # the width of the bars

fig, axes = plt.subplots(2, 1, figsize=(5, 4))
plt.subplots_adjust(hspace = 0.6)
for i in [0, 1]:
    if i == 0:
        col = "pearson_rna"
    else:
        col = "pearson_adt"
    rects0 = axes[i].bar(x - width/2, data[(data['fmask'] == 0.1)][col], width, label = '0.1', color = '#8dd3c7')
    rects1 = axes[i].bar(x + width/2 + 0.02, data[(data['fmask'] == 0.3)][col], width, label = '0.3', color = '#fc9d62')
    rects2 = axes[i].bar(x + width*3/2 + 0.04, data[(data['fmask'] == 0.5)][col], width, label = '0.5', color = '#bebada')
    rects3 = axes[i].bar(x + width*5/2 + 0.06, data[(data['fmask'] == 0.7)][col], width, label = '0.7', color = '#fb8072')
    rects4 = axes[i].bar(x + width*7/2 + 0.08, data[(data['fmask'] == 0.9)][col], width, label = '0.9', color = '#80b1d3')
    

    axes[i].bar_label(rects0, padding = 2, fmt='%.3f', fontsize = 8, rotation = 45)
    axes[i].bar_label(rects1, padding = 2, fmt='%.3f', fontsize = 8, rotation = 45)
    axes[i].bar_label(rects2, padding = 2, fmt='%.3f', fontsize = 8, rotation = 45)
    axes[i].bar_label(rects3, padding = 2, fmt='%.3f', fontsize = 8, rotation = 45)
    axes[i].bar_label(rects4, padding = 2, fmt='%.3f', fontsize = 8, rotation = 45)


    axes[i].tick_params(axis='x', direction = 'in', bottom = False)
    axes[i].tick_params(axis='y', direction = 'out', labelsize = 10, length = 3)
    axes[i].set_xticks(x + 0.1)
    axes[i].set_xticklabels(labels, size = 10)
    axes[i].set_ylim(bottom = 0., top = 1.01)
    axes[i].set_yticks(np.arange(0., 1.01, step = 0.2))
    axes[i].set_ylabel("Pearson r", fontsize = 12)
    if i == 0:
        axes[i].set_title("Query imputation for missing RNA", fontsize = 10, y = 1.1)
        axes[i].legend(loc = (0.4, 0.95), ncol = 3, fontsize = 8, frameon = False)
    else:
        axes[i].set_title("Query imputation for missing ADT", fontsize = 10, y = 1.1)
        

    for spine in ['top', 'right']:
        axes[i].spines[spine].set_color('none')


plt.savefig('figure4_2.svg',dpi = 300, bbox_inches = 'tight')
plt.show()
